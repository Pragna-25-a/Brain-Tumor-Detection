# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'C:\Users\zoyak\Downloads\brain-tumor\runs\detect\train3\weights\best.pt')
results = trained_model(r'C:\Users\zoyak\Downloads\brain-tumor\testing images\sample img2.png')
# Out:
# image 1/1 C:\Users\zoyak\Downloads\brain-tumor\testing images\sample img2.png: 320x640 1 positive, 812.2ms
# Speed: 21.9ms preprocess, 812.2ms inference, 10.8ms postprocess per image at shape (1, 3, 320, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
